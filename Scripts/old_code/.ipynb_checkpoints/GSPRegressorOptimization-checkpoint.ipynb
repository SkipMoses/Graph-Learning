# %%
import numpy as np
import cvxpy as cp
import itertools as it
import matplotlib.pyplot as plt
from scipy import sparse
from pygsp import graphs, filters
from numpy.linalg import inv
import networkx as nx
import random as rand
from sklearn import linear_model as lm

# %run Scripts/SyntheticDataGenerator.py
# %run Scripts/DongsAlgorithm.py
# %run Scripts/Metrics.py
# %run Scripts/GSPRegression.py

# For reproducing results 
seed = 0

# %%
G = nx.erdos_renyi_graph(20, 0.2, seed = 7)
S1 = RandomSignal(G, 100, 0, .5, 0)
L_ER = nx.laplacian_matrix(G).toarray()
normL_ER = (L_ER.shape[0]/np.trace(L_ER))*L_ER
E = GL_SigRep(0.002, .9, S1, .001, 100)
ComputeMetrics(E, normL_ER, .01)
# Out:
# {'Precision': 0.5394736842105263,
#  'Recall': 0.8723404255319149,
#  'F-Measure': 0.6666666666666667,
#  'Relative Error': 0.4268711249306668,
#  'SSE': 0.18221895729957296}

# %%
num_obser = 20
num_trials = 5
dist_vec = ['uniform', 'normal', 'binomial']
param_vec = [['0,1'], ['0,.5', '0,.5'], ['1,.5']]
M = generate_trials(num_obser, num_trials, dist_vec, param_vec, seed)
b = np.ones(4)
S2 = RandomRegressorSignal(G, 0, .5, b, M, seed)

# %%
# Optimal hyperparamerters for signal w/o regressors
E = GL_SigRep(0.002, .9, S2, .001, 100)
ComputeMetrics(E, normL_ER, .01)
# Out:
# {'Precision': 0.3013698630136986,
#  'Recall': 0.9361702127659575,
#  'F-Measure': 0.45595854922279794,
#  'Relative Error': 0.5953647259020171,
#  'SSE': 0.3544591568483839}

# %%
# Hyperparameters optimized by first optimizing a, and then optimizing b.
a = 0.001
b = 0.14040404040404042
Etemp = GL_SigRep(a, b, S2, .001, 100) 
ComputeMetrics(Etemp, normL_ER, .01)
# Out:
# {'Precision': 0.38202247191011235,
#  'Recall': 0.723404255319149,
#  'F-Measure': 0.5,
#  'Relative Error': 0.566794712925493,
#  'SSE': 0.321256246600292}

# %%
# Hyperparameters optimized by alternating optimization
a = 0.001106060606060606
b = 0.49949494949494955
Etemp = GL_SigRep(a, b, S2, .001, 100) 
ComputeMetrics(Etemp, normL_ER, .01)
# Out:
# {'Precision': 0.30612244897959184,
#  'Recall': 0.9574468085106383,
#  'F-Measure': 0.46391752577319584,
#  'Relative Error': 0.5952578056786858,
#  'SSE': 0.3543318552214041}

# %%
a = 0.0092
b = 1
Etemp = GSP_Regression(a, b, S2, M, .001, 100)[0]
ComputeMetrics(Etemp, normL_ER, .01)
# Out:
# {'Precision': 0.379746835443038,
#  'Recall': 0.6382978723404256,
#  'F-Measure': 0.4761904761904762,
#  'Relative Error': 0.5812256273225748,
#  'SSE': 0.3378232298565206}

# %%
a = 0.001106060606060606
b = 0.49949494949494955
ratio = np.linspace(0.45, 0.55, 100)
LGs = [GL_SigRep(a, r, S2, .001, 100) for r in ratio]  
Metrics = [ComputeMetrics(e, normL_ER, .01) for e in LGs]
fmes = [i['F-Measure'] for i in Metrics]

# %%
#---------------------------------------------------------------------------------------------------------------------
# Optimize a
#(.001, 1, 100) fmes = 0.42152466367713 a = .001
#(.0001, .0015, 100) fmes = 0.44554455445544555 a = 0.001

# Optimize b
#(.5, 1.5, 100) fmes = 0.4568527918781726 b = 0.5
#(.1, .9, 100) fmes = 0.5 b = 0.14040404040404042

# Optimize a
#(.0005, .0015, 100) fmes = .5 a = 0.001, b = 0.14040404040404042
#---------------------------------------------------------------------------------------------------------------------
# Optimize with alternating 

# b = 1
#(.001, 1, 100) fmes = 0.42152466367713 a = .001

# a = 0.001
#(.5, 1.5, 100) fmes = 0.4568527918781726, b = 0.5

# b = 0.5
#(0.0005, 0.0015, 100) fmes = 0.46391752577319584, a = 0.001106060606060606

# a = 0.001106060606060606 
#(0.45, 0.55, 100) fmes = 0.46391752577319584, b = 0.49949494949494955 
#---------------------------------------------------------------------------------------------------------------------
# Optimize Precision
#---------------------------------------------------------------------------------------------------------------------
for i in range(len(fmes)):
    print(i, fmes[i], ratio[i])
# Out:
# 0 0.41530054644808745 0.45
# 1 0.41530054644808745 0.451010101010101
# 2 0.4239130434782608 0.45202020202020204
# 3 0.4385026737967915 0.45303030303030306
# 4 0.4385026737967915 0.4540404040404041
# 5 0.4385026737967915 0.45505050505050504
# 6 0.4385026737967915 0.45606060606060606
# 7 0.4385026737967915 0.45707070707070707
# 8 0.4408602150537635 0.4580808080808081
# 9 0.4408602150537635 0.4590909090909091
# 10 0.4408602150537635 0.4601010101010101
# 11 0.4408602150537635 0.46111111111111114
# 12 0.4408602150537635 0.46212121212121215
# 13 0.4361702127659575 0.46313131313131317
# 14 0.4361702127659575 0.46414141414141413
# 15 0.4361702127659575 0.46515151515151515
# 16 0.4361702127659575 0.46616161616161617
# 17 0.4361702127659575 0.4671717171717172
# 18 0.4361702127659575 0.4681818181818182
# 19 0.4361702127659575 0.4691919191919192
# 20 0.44444444444444436 0.47020202020202023
# 21 0.4421052631578947 0.47121212121212125
# 22 0.4421052631578947 0.47222222222222227
# 23 0.4421052631578947 0.4732323232323232
# 24 0.4421052631578947 0.47424242424242424
# 25 0.4397905759162304 0.47525252525252526
# 26 0.4397905759162304 0.4762626262626263
# 27 0.4397905759162304 0.4772727272727273
# 28 0.4397905759162304 0.4782828282828283
# 29 0.44791666666666663 0.4792929292929293
# 30 0.44791666666666663 0.48030303030303034
# 31 0.44791666666666663 0.48131313131313136
# 32 0.44791666666666663 0.4823232323232324
# 33 0.44791666666666663 0.48333333333333334
# 34 0.44791666666666663 0.48434343434343435
# 35 0.45595854922279794 0.48535353535353537
# 36 0.45595854922279794 0.4863636363636364
# 37 0.45595854922279794 0.4873737373737374
# 38 0.45595854922279794 0.4883838383838384
# 39 0.45595854922279794 0.48939393939393944
# 40 0.45595854922279794 0.49040404040404045
# 41 0.45595854922279794 0.4914141414141414
# 42 0.45595854922279794 0.49242424242424243
# 43 0.45595854922279794 0.49343434343434345
# 44 0.45595854922279794 0.49444444444444446
# 45 0.45595854922279794 0.4954545454545455
# 46 0.45595854922279794 0.4964646464646465
# 47 0.45595854922279794 0.4974747474747475
# 48 0.45595854922279794 0.49848484848484853
# 49 0.46391752577319584 0.49949494949494955
# 50 0.4615384615384615 0.5005050505050506
# 51 0.4615384615384615 0.5015151515151516
# 52 0.4568527918781726 0.5025252525252526
# 53 0.4568527918781726 0.5035353535353536
# 54 0.4568527918781726 0.5045454545454546
# 55 0.4568527918781726 0.5055555555555555
# 56 0.4568527918781726 0.5065656565656566
# 57 0.4568527918781726 0.5075757575757576
# 58 0.4568527918781726 0.5085858585858586
# 59 0.4568527918781726 0.5095959595959596
# 60 0.4568527918781726 0.5106060606060606
# 61 0.4568527918781726 0.5116161616161616
# 62 0.4568527918781726 0.5126262626262627
# 63 0.4568527918781726 0.5136363636363637
# 64 0.4568527918781726 0.5146464646464647
# 65 0.4568527918781726 0.5156565656565657
# 66 0.4568527918781726 0.5166666666666667
# 67 0.4568527918781726 0.5176767676767677
# 68 0.4568527918781726 0.5186868686868688
# 69 0.4568527918781726 0.5196969696969698
# 70 0.4568527918781726 0.5207070707070708
# 71 0.4568527918781726 0.5217171717171718
# 72 0.4568527918781726 0.5227272727272727
# 73 0.4568527918781726 0.5237373737373738
# 74 0.4568527918781726 0.5247474747474747
# 75 0.4568527918781726 0.5257575757575758
# 76 0.4568527918781726 0.5267676767676768
# 77 0.4568527918781726 0.5277777777777778
# 78 0.4568527918781726 0.5287878787878788
# 79 0.4568527918781726 0.5297979797979798
# 80 0.4568527918781726 0.5308080808080808
# 81 0.4568527918781726 0.5318181818181819
# 82 0.4568527918781726 0.5328282828282829
# 83 0.4568527918781726 0.5338383838383839
# 84 0.4568527918781726 0.5348484848484849
# 85 0.4568527918781726 0.5358585858585859
# 86 0.4568527918781726 0.5368686868686869
# 87 0.4568527918781726 0.537878787878788
# 88 0.4568527918781726 0.538888888888889
# 89 0.4568527918781726 0.53989898989899
# 90 0.4568527918781726 0.540909090909091
# 91 0.4568527918781726 0.5419191919191919
# 92 0.4568527918781726 0.542929292929293
# 93 0.4568527918781726 0.543939393939394
# 94 0.4568527918781726 0.544949494949495
# 95 0.4568527918781726 0.545959595959596
# 96 0.4568527918781726 0.546969696969697
# 97 0.4568527918781726 0.547979797979798
# 98 0.4568527918781726 0.548989898989899
# 99 0.4568527918781726 0.55

# %%
a = 0.0092
b = 0.49949494949494955
ratio = np.linspace(0.01, 2.1, 100)
LGs = [GSP_Regression(a, r, S2, M, .001, 100)[0] for r in ratio]  
Metrics = [ComputeMetrics(e, normL_ER, .01) for e in LGs]
fmes = [i['F-Measure'] for i in Metrics]

# %%
# b = 1
#(0.1, 1.1, 100) fmes = 0.26666666666666666, a = 0.1101010101010101, 0.22121212121212122 <- This is strange,
# Why did this work!
#(.001, .2, 100) # ERROR 'list' object has no attribute 'transpose' line 55
#(.009, .2, 100) # ERROR ""
# Error is an issue with how regression coefficents are being recoverd.
# Removing this and proceeding.

#(.01, 2, 100) ERROR: invalid index to scalar variable.
# For some reason the return statement when threshold was met was not working as intended.
#-------------------------------------------------------------------------------------------------------------------
# b = 1
# (.01, 2, 100) fmes = 0.4406779661016949, a = 0.01
# (0.05, .15, 100) Seems like a poor way to optimize
#-------------------------------------------------------------------------------------------------------------------
# a = 0.01, b = 1
# (.5, 1.5, 100) No good
# (.001, 10, 100) fmes = 0.42152466367713, a = 0.001
# (0.0001, 0.01, 100) fmes = 0.4761904761904762 a = 0.0092 
# (0.009, 0.0093, 100) fmes = 0.4761904761904762 a = 0.0092

# a = 0.0092
# (0.01, 2.1, 100) fmes = 0.4761904761904762 a = 1.0022222222222223
for i in range(len(fmes)):
    print(i, fmes[i], ratio[i])
# Out:
# 0 0.07547169811320754 0.01
# 1 0.17241379310344826 0.031111111111111117
# 2 0.23333333333333334 0.05222222222222223
# 3 0.25806451612903225 0.07333333333333335
# 4 0.23728813559322032 0.09444444444444446
# 5 0.27692307692307694 0.11555555555555556
# 6 0.3098591549295775 0.13666666666666671
# 7 0.3098591549295775 0.15777777777777782
# 8 0.3055555555555556 0.17888888888888893
# 9 0.3209876543209876 0.20000000000000004
# 10 0.3209876543209876 0.22111111111111115
# 11 0.3218390804597701 0.24222222222222228
# 12 0.3218390804597701 0.2633333333333334
# 13 0.3370786516853933 0.2844444444444445
# 14 0.28571428571428575 0.30555555555555564
# 15 0.28571428571428575 0.3266666666666667
# 16 0.28571428571428575 0.34777777777777785
# 17 0.3058823529411765 0.368888888888889
# 18 0.3058823529411765 0.39000000000000007
# 19 0.3617021276595745 0.4111111111111112
# 20 0.37499999999999994 0.4322222222222223
# 21 0.37499999999999994 0.4533333333333334
# 22 0.37499999999999994 0.47444444444444456
# 23 0.3404255319148936 0.49555555555555564
# 24 0.3404255319148936 0.5166666666666668
# 25 0.3617021276595745 0.5377777777777779
# 26 0.3617021276595745 0.558888888888889
# 27 0.3617021276595745 0.5800000000000001
# 28 0.3673469387755102 0.6011111111111113
# 29 0.3673469387755102 0.6222222222222223
# 30 0.3673469387755102 0.6433333333333334
# 31 0.3673469387755102 0.6644444444444446
# 32 0.3673469387755102 0.6855555555555557
# 33 0.3673469387755102 0.7066666666666668
# 34 0.3673469387755102 0.727777777777778
# 35 0.3673469387755102 0.748888888888889
# 36 0.3673469387755102 0.7700000000000001
# 37 0.3673469387755102 0.7911111111111113
# 38 0.3673469387755102 0.8122222222222224
# 39 0.3673469387755102 0.8333333333333335
# 40 0.3673469387755102 0.8544444444444446
# 41 0.39999999999999997 0.8755555555555558
# 42 0.41818181818181815 0.8966666666666668
# 43 0.4210526315789473 0.9177777777777779
# 44 0.423728813559322 0.9388888888888891
# 45 0.4516129032258065 0.9600000000000002
# 46 0.464 0.9811111111111113
# 47 0.4761904761904762 1.0022222222222223
# 48 0.453125 1.0233333333333337
# 49 0.46268656716417916 1.0444444444444447
# 50 0.45070422535211263 1.0655555555555558
# 51 0.43971631205673756 1.086666666666667
# 52 0.4580152671755725 1.107777777777778
# 53 0.4580152671755725 1.128888888888889
# 54 0.4580152671755725 1.1500000000000001
# 55 0.4580152671755725 1.1711111111111114
# 56 0.43283582089552236 1.1922222222222225
# 57 0.43795620437956206 1.2133333333333336
# 58 0.4316546762589928 1.2344444444444447
# 59 0.43971631205673756 1.2555555555555558
# 60 0.43971631205673756 1.2766666666666668
# 61 0.4460431654676259 1.2977777777777781
# 62 0.4460431654676259 1.3188888888888892
# 63 0.4460431654676259 1.3400000000000003
# 64 0.4460431654676259 1.3611111111111114
# 65 0.4477611940298508 1.3822222222222225
# 66 0.4477611940298508 1.4033333333333335
# 67 0.4477611940298508 1.4244444444444446
# 68 0.4477611940298508 1.445555555555556
# 69 0.4477611940298508 1.466666666666667
# 70 0.4477611940298508 1.487777777777778
# 71 0.4477611940298508 1.5088888888888892
# 72 0.4477611940298508 1.5300000000000002
# 73 0.4477611940298508 1.5511111111111113
# 74 0.4477611940298508 1.5722222222222226
# 75 0.4477611940298508 1.5933333333333337
# 76 0.4477611940298508 1.6144444444444448
# 77 0.4477611940298508 1.6355555555555559
# 78 0.4477611940298508 1.656666666666667
# 79 0.4477611940298508 1.677777777777778
# 80 0.4161073825503355 1.6988888888888891
# 81 0.4161073825503355 1.7200000000000004
# 82 0.4161073825503355 1.7411111111111115
# 83 0.4161073825503355 1.7622222222222226
# 84 0.4161073825503355 1.7833333333333337
# 85 0.4161073825503355 1.8044444444444447
# 86 0.4161073825503355 1.8255555555555558
# 87 0.4161073825503355 1.8466666666666671
# 88 0.4161073825503355 1.8677777777777782
# 89 0.4161073825503355 1.8888888888888893
# 90 0.4161073825503355 1.9100000000000004
# 91 0.4161073825503355 1.9311111111111114
# 92 0.4161073825503355 1.9522222222222225
# 93 0.4161073825503355 1.9733333333333338
# 94 0.4161073825503355 1.994444444444445
# 95 0.4161073825503355 2.0155555555555558
# 96 0.4161073825503355 2.036666666666667
# 97 0.4161073825503355 2.057777777777778
# 98 0.4161073825503355 2.0788888888888892
# 99 0.4161073825503355 2.1

# %%
# For some reason only the first pass learned a laplacian.
for e in LGs:
    print(e.shape)
# Out:
# (20, 20)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)
# (20,)

# %%
def GSP_Regression_test(a, b, Signal, P, tol, max_itr):
    print("Begining GSP Regression:")
    Y = Signal
    print("Initial shape of Y " + str(Y.shape))
    R = np.zeros(Y.shape)
    print("Initial shape of R " + str(R.shape))
    I = np.matrix(np.identity(Signal.shape[0]))
    L = Problem1(a, b, Y)
    print("Initial shape of L " + str(L.shape))
    for i in range(1,max_itr):
        print("___________________________________________________________________")
        print(str(i) + " pass")
        temp = L
        print("Current shape of L is " + str(L.shape) + " Learing Y.")
        # Closed form solution given by Dong et al.
        Y = (inv(I + a*L))@(Signal - R)
        print("Current shape of Y is " + str(Y.shape) + " Learning R.")
        # Find new Regressor matrix
        R = Signal - Y
        print("Current shape of R is " + str(R.shape) + " Learning L.")
        # Find a new L given Y.
        L = Problem1(a, b, Y)
        print("Shape of learning L is " + str(L.shape) + " Finished iteration")
        # Check if we are within the tolerance
        if(np.all(abs(temp - L) < tol)):
                print("Tolerance met.")
                return np.asarray(L)
        print("Tolerance not met.")
    #b = (inv(P.transpose()@P)@P.transpose)@np.matrix.flatten(R, 'F')
    #return [np.asarray(L), Y, b]
    print("Max numeber of iterations reached.")
    return [np.asarray(L), Y]

# %%
E = GSP_Regression_test2(.01, 1, S2, M, .001, 100)[0]
# Out:
# Begining GSP Regression:
# Initial shape of Y (20, 5)
# Initial shape of R (20, 5)
# Initial shape of L (20, 20)
# ___________________________________________________________________
# 1 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 2 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 3 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 4 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 5 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 6 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 7 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 8 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 9 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 10 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 11 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 12 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 13 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 14 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 15 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 16 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 17 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 18 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 19 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 20 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 21 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 22 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 23 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 24 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 25 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 26 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 27 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 28 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 29 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 30 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 31 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 32 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 33 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 34 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 35 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 36 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 37 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 38 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 39 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 40 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 41 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 42 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 43 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 44 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 45 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 46 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance met.

# %%
E[1].shape
# Out:
# (20,)

# %%
E = GSP_Regression_test2(.01, 1, S2, M, .001, 100)[0]
ComputeMetrics(E, normL_ER, .01)
# Out:
# Begining GSP Regression:
# Initial shape of Y (20, 5)
# Initial shape of R (20, 5)
# Initial shape of L (20, 20)
# ___________________________________________________________________
# 1 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 2 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 3 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 4 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 5 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 6 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 7 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 8 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 9 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 10 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 11 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 12 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 13 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 14 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 15 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 16 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 17 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 18 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 19 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 20 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 21 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 22 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 23 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 24 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 25 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 26 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 27 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 28 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 29 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 30 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 31 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 32 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 33 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 34 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 35 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 36 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 37 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 38 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 39 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 40 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 41 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 42 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 43 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 44 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 45 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 46 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 47 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 48 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 49 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 50 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 51 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 52 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 53 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 54 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 55 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 56 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 57 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 58 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 59 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 60 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 61 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 62 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 63 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 64 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 65 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 66 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 67 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 68 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 69 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 70 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 71 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 72 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 73 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 74 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 75 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 76 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 77 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 78 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 79 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 80 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 81 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 82 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 83 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 84 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 85 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 86 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 87 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 88 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 89 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 90 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 91 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 92 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 93 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 94 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 95 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 96 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 97 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 98 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# ___________________________________________________________________
# 99 pass
# Current shape of L is (20, 20) Learing Y.
# Current shape of Y is (20, 5) Learning R.
# Current shape of R is (20, 5) Learning L.
# Shape of learning L is (20, 20) Finished iteration
# Tolerance not met.
# Max numeber of iterations reached.
# {'Precision': 0.36619718309859156,
#  'Recall': 0.5531914893617021,
#  'F-Measure': 0.4406779661016949,
#  'Relative Error': 0.5906722870154247,
#  'SSE': 0.3488937506480323}

# %%
E[0].shape
# Out:
# (20, 20)

# %%
def GSP_Regression_test2(a, b, Signal, P, tol, max_itr):
    print("Begining GSP Regression:")
    Y = Signal
    print("Initial shape of Y " + str(Y.shape))
    R = np.zeros(Y.shape)
    print("Initial shape of R " + str(R.shape))
    I = np.matrix(np.identity(Signal.shape[0]))
    L = Problem1(a, b, Y)
    print("Initial shape of L " + str(L.shape))
    for i in range(1,max_itr):
        print("___________________________________________________________________")
        print(str(i) + " pass")
        temp = L
        print("Current shape of L is " + str(L.shape) + " Learing Y.")
        # Closed form solution given by Dong et al.
        Y = (inv(I + a*L))@(Signal - R)
        print("Current shape of Y is " + str(Y.shape) + " Learning R.")
        # Find new Regressor matrix
        R = Signal - Y
        print("Current shape of R is " + str(R.shape) + " Learning L.")
        # Find a new L given Y.
        L = Problem1(a, b, Y)
        print("Shape of learning L is " + str(L.shape) + " Finished iteration")
        # Check if we are within the tolerance
        if(np.all(abs(temp - L) < tol)):
                print("Tolerance met.")
                break
        print("Tolerance not met.")
    #b = (inv(P.transpose()@P)@P.transpose)@np.matrix.flatten(R, 'F')
    #return [np.asarray(L), Y, b]
    print("Max numeber of iterations reached.")
    return [np.asarray(L), Y]
