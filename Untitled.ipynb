# %%
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
import cvxpy as cp
import itertools as it

def sigmoid(x):
  
    z = np.exp(-x)
    sig = 1 / (1 + z)

    return sig
def generate_signal(h, chi):
    P = (chi@h)
    X = [sigmoid(p) for p in P]
    for i in range(len(X)):
        test = np.random.uniform(0,1)
        if test < X[i]:
            X[i] = 1
        else:
            X[i] = 0
    return X
def term_given_X(y,w,X):
    return y.T@X@w - cp.sum(cp.logistic(X@w))

def term_given_w(y,w,X):
    return y.T@X@w - cp.sum(cp.logistic(X@w))

def generate_p(alpha, h, chi):
    P = (chi@h + alpha*np.ones(len(h)))
    return P

# %%
N = 20
M = 100
seed = 123
G = nx.fast_gnp_random_graph(N, .2, seed = seed)
np.random.seed(seed)
for s,t in G.edges:
    G[s][t]['weight'] = np.random.uniform(0,1)
A = nx.adjacency_matrix(G)

# %%
np.random.seed(seed)
h = np.random.normal(0,1,N)
alpha = .2

# %%
Y = []
for i in range(M):
    signal = generate_signal(h,A)
    Y.append(signal)
    temp = {n:signal[n] for n in G.nodes()}
    nx.set_node_attributes(G, temp, name = "Round " + str(i+1))
Y = np.transpose(Y)
Y.shape
# Out:
# (20, 100)

# %%
h_vals
# Out:
# [array([ 1.64140418,  1.15235603, -0.60180913, -1.21566206, -0.54841834,
#          1.06538295, -0.52392241,  0.54598799, -0.56588012,  0.34316416,
#          0.52814197,  0.98583325,  1.43324013,  1.31022893, -0.53017151,
#         -0.14701874, -1.1735251 , -0.23568529,  0.02431714, -0.40395993]),
#  array([[ 1.59354482e+00],
#         [ 2.13740461e+00],
#         [-9.23580232e-01],
#         [-8.75259679e-01],
#         [-5.64529262e-01],
#         [ 2.08515063e+01],
#         [-9.62505527e-01],
#         [ 5.73069843e-01],
#         [-4.81198481e-01],
#         [-4.10027865e+01],
#         [ 5.18388393e-01],
#         [-2.31151257e+00],
#         [-2.62728745e+02],
#         [ 2.86723282e+02],
#         [-6.23980039e-01],
#         [-1.76467193e-01],
#         [-1.18723616e+00],
#         [-4.65732609e-01],
#         [ 1.50690301e-01],
#         [-2.44353377e-01]]),
#  array([[ -39.07657833],
#         [ -51.94577895],
#         [  28.3244021 ],
#         [  33.49682346],
#         [  13.7282661 ],
#         [   4.26557063],
#         [-157.11558646],
#         [ -89.41196681],
#         [   7.09263876],
#         [ -39.13217964],
#         [-421.8611544 ],
#         [  17.06381699],
#         [-263.80970335],
#         [ 288.78222851],
#         [  26.60471246],
#         [  53.30704588],
#         [  24.93003704],
#         [  22.5276175 ],
#         [ 573.93946652],
#         [ -31.70967802]]),
#  array([[  8611.01530546],
#         [   -90.37348718],
#         [  4927.27836209],
#         [ 10156.9349002 ],
#         [  3211.7003366 ],
#         [ -5812.35817916],
#         [ -3931.97693284],
#         [  2805.66382298],
#         [   745.38078872],
#         [  3419.56658292],
#         [  1579.8513542 ],
#         [ -6642.00481159],
#         [  -237.56569701],
#         [ -4312.15954413],
#         [  3046.33585701],
#         [ 18888.48879149],
#         [ -9285.37252127],
#         [  3177.80457003],
#         [   621.99981986],
#         [-30880.20931839]]),
#  array([[  7037.41250287],
#         [ -3567.37008554],
#         [ 13490.90492548],
#         [ 18455.87436836],
#         [  8544.76905602],
#         [-73845.94713948],
#         [ 61837.10407135],
#         [ -7453.98469638],
#         [-11757.00011059],
#         [  9712.96233384],
#         [ -2187.23623281],
#         [  -712.78240806],
#         [ -2228.73935982],
#         [  2966.2493121 ],
#         [  2186.54268335],
#         [ 14873.91808104],
#         [ -3162.18040825],
#         [ -5984.87369602],
#         [  1559.79897296],
#         [-29765.42217041]]),
#  None]

# %%
# Define variables 
A_var = cp.Variable((N,N), symmetric = True)
Lap = cp.diag(A_var@np.ones((N,1))) - A_var
h_var = cp.Variable((N,1))
h_init = np.random.normal(0,1,N)
print("CP variables built.")
# Adjacency Matrix Constraints
constraints = [cp.diag(A_var) == 0,
                A_var - cp.diag(cp.diag(A_var)) >= 0]
A_obj = cp.Maximize(sum([term_given_w(y,h_init,A_var) for y in Y.T]) - alpha*cp.norm(Lap, 'fro'))

P_init = cp.Problem(A_obj, constraints)
P_init.solve()
A_init = A_var.value
A_vals = [A_init]
h_vals = [h_init]
for i in range(10):
    A_cur = cp.Variable((N,N), symmetric = True)
    Lap = cp.diag(A_cur@np.ones((N,1))) - A_cur
    h_cur = cp.Variable((N,1))
    constraints = [cp.diag(A_cur) == 0,
                A_cur - cp.diag(cp.diag(A_cur)) >= 0]
    hconstraints = [cp.sum(h_cur) == 0,
                   cp.max(h_cur) <= 1,
                   cp.min(h_cur) >= -1]
    h_obj = cp.Maximize(sum([term_given_X(y,h_cur,A_vals[len(A_vals)-1]) for y in Y.T]))
    P_cur = cp.Problem(h_obj, hconstraints)
    P_cur.solve()
    h_vals.append(h_cur.value)
    A_obj = cp.Maximize(sum([term_given_w(y,h_vals[len(h_vals)-1],A_cur) for y in Y.T]) - alpha*cp.norm(Lap, 'fro'))
    P_cur2 = cp.Problem(A_obj, constraints)
    P_cur2.solve()
    A_vals.append(A_cur.value)
# Out:
# CP variables built.

# %%
A_est = A_vals[9]
mean = np.mean(A_est)
sd = np.std(A_est)
for i in range(len(A_est)):
    for j in range(len(A_est[i])):
        if A_est[i][j] < .05:
            A_est[i][j] = 0

# %%
plt.imshow(A_est, cmap='jet', interpolation='nearest')
plt.colorbar()
plt.show()
plt.savefig("est_A_heatmap.png")

# %%
im1 = plt.imshow(A.toarray(), cmap='jet', interpolation='nearest')
plt.colorbar()
plt.show()

# %%
edges,weights = zip(*nx.get_edge_attributes(est_G,'weight').items())
nodes, signal = zip(*nx.get_node_attributes(G,'Round 3').items())
node_color = ['grey']*len(signal)
for i in range(len(signal)):
    if signal[i] == 1:
        node_color[i] = 'black'
size = [w*5 for w in weights]
pos = nx.circular_layout(est_G)
ec = nx.draw_networkx_edges(est_G, pos, 
                            edgelist=edges, 
                            edge_color=weights, 
                            width=size,
                            edge_cmap=plt.cm.jet)
nc = nx.draw_networkx_nodes(est_G,pos,
                            nodelist=nodes,
                            node_color=node_color, 
                            node_size = 100,
                            alpha = .9)
plt.colorbar(ec)
plt.savefig("pictures/est_graph.png")

# %%
edges,weights = zip(*nx.get_edge_attributes(G,'weight').items())
nodes, signal = zip(*nx.get_node_attributes(G,'Round 3').items())
node_color = ['grey']*len(signal)
for i in range(len(signal)):
    if signal[i] == 1:
        node_color[i] = 'black'
size = [w*5 for w in weights]
pos = nx.circular_layout(G)
ec = nx.draw_networkx_edges(G, pos, 
                            edgelist=edges, 
                            edge_color=weights, 
                            width=size,
                            edge_cmap=plt.cm.jet)
nc = nx.draw_networkx_nodes(G,pos,
                            nodelist=nodes,
                            node_color=node_color, 
                            node_size = 100,
                            alpha = .9)
plt.colorbar(ec)
plt.savefig("pictures/gt_graph.png")

# %%
nx.draw_circular(G)

# %%
print(h_vals[9])
# Out:
# [[-0.04565941]
#  [-0.91187155]
#  [ 0.1818177 ]
#  [ 0.99931965]
#  [-0.0491176 ]
#  [-0.01084595]
#  [ 0.16264981]
#  [-0.99926336]
#  [ 0.37319554]
#  [-0.99940876]
#  [-0.39723868]
#  [ 0.99939257]
#  [-0.57349828]
#  [ 0.14021187]
#  [ 0.79871495]
#  [ 0.38396029]
#  [-0.63091393]
#  [-0.09615242]
#  [ 0.99918555]
#  [-0.32447798]]
